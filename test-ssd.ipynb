# %%
# %matplotlib inline
import sys
import numpy as np
from matplotlib import pyplot as plt
sys.path.insert(0, '/workspace/caffe-ssd/python')
import caffe
caffe.set_device(0)
caffe.set_mode_gpu()
net = caffe.Net('/workspace/train.prototxt',
                caffe.TRAIN)

# %%
_ = net.forward()

# %%
_R_MEAN = 123.68
_G_MEAN = 116.78
_B_MEAN = 103.94
PIXEL_MEAN_RGB = np.array([_R_MEAN, _G_MEAN, _B_MEAN]).reshape((1, 1, 3))
PIXEL_MEAN_BGR = PIXEL_MEAN_RGB[..., ::-1]

# %%
img = net.blobs['data'].data
seg = net.blobs['seg_gt'].data
plt.imshow((img.transpose((0,2,3,1))[19,...,::-1] + PIXEL_MEAN_RGB).astype(np.uint8))
plt.show()

# %%
plt.imshow(seg[19,7,...])
plt.show()
plt.imshow(seg[15,12,...])
plt.show()

# %%
# %connect_info
